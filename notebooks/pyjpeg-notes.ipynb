# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Notes made during live coding

# %%
from pathlib import Path

import matplotlib.pyplot as plt

import jpeg.pyjpeg
from helpers import (
    load_img,
    plot_filter,
    plot_pixel_values
)

image_path = Path('..', 'images', 'lena512.bmp')
im = load_img(image_path)

fig, ax = plt.subplots(1, 1, figsize=(12, 8))
ax.imshow(im, cmap='gray', vmin=0, vmax=255)
ax.axis('off')
plt.tight_layout()
_ = plt.savefig(Path('..', 'images', 'lena.png'))

# %%
import numpy as np

# %%
dct_values_left = jpeg.pyjpeg.discrete_cosine(np.arange(8), 4).reshape(8, 1)
dct_values_right = jpeg.pyjpeg.discrete_cosine(np.arange(8), 6).reshape(1, 8)

plot_filter(dct_values_left @ dct_values_right)
# Out:
# <ggplot: (292339217)>

# %%
im_dct = jpeg.pyjpeg.dct(im)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 8))
axes[0].imshow(im, cmap='gray', vmin=0, vmax=255)
axes[1].imshow(im_dct, cmap='gray', vmin=0, vmax=255)
for ax in axes:
    ax.axis('off')
plt.tight_layout()

# %%
im.min(), im.max()
# Out:
# (25.0, 245.0)

# %%
im_dct.min(), im_dct.max()
# Out:
# (-745.7499999999998, 764.9999999999999)

# %%
plot_pixel_values(im_dct)
# Out:
# /Users/cor/.virtualenvs/pyjpeg/lib/python3.7/site-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 10695'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# <ggplot: (328409557)>
